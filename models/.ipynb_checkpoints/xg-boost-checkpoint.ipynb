# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
# !pip install xgboost
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Read Files
df = pd.read_excel('data.xlsx')

# Specify the columns you want to drop
# columns_to_drop = ['New']

# Drop the columns
df = df.drop(columns=columns_to_drop)

df.head()

# Separate the features (X) and target variable (y)
X = df.drop('DroppedOut', axis=1)
y = df['DroppedOut']
# Convert y to a numpy array
y = np.array(y)

# Perform z-score normalization on the features 
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 8
#       2 df = pd.read_excel('data.xlsx')
#       4 # Specify the columns you want to drop
#       5 # columns_to_drop = ['New']
#       6
#       7 # Drop the columns
# ----> 8 df = df.drop(columns=columns_to_drop)
#      10 df.head()
#      12 # Separate the features (X) and target variable (y)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['New'] not found in axis"

# %%
# Lists to store the metrics of each fold
confusion_matrices = []
accuracies = []
precisions = []
recalls = []
f1_scores = []

# Perform stratified K-fold cross-validation with 8 folds
skf = StratifiedKFold(n_splits=8)

# Train an XGBoost classifier on each fold
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

for train_index, test_index in skf.split(X_normalized, y):
    X_train, X_test = X_normalized[train_index], X_normalized[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # Train the XGBoost classifier
    xgb.fit(X_train, y_train)
    
    # Make predictions on the test set
    y_pred = xgb.predict(X_test)
    
    # Compute the confusion matrix and store it in the list
    cm = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(cm)
    
    # Compute the metrics and store them in the lists
    accuracies.append(accuracy_score(y_test, y_pred))
    precisions.append(precision_score(y_test, y_pred, average='weighted'))
    recalls.append(recall_score(y_test, y_pred, average='weighted'))
    f1_scores.append(f1_score(y_test, y_pred, average='weighted'))

# %%
# Print the confusion matrices
for i, cm in enumerate(confusion_matrices):
    print(f"Confusion matrix for fold {i+1}:\n", cm)
    
# Compute the macro averages
macro_precision = precision_score(y_test, y_pred, average='macro')
macro_recall = recall_score(y_test, y_pred, average='macro')
macro_f1 = f1_score(y_test, y_pred, average='macro')

# Print the metrics
print("Model Accuracy:", np.mean(accuracies))
print("Weighted Average Precision:", np.mean(precisions))
print("Weighted Average Recall:", np.mean(recalls))
print("Weighted Average F1-score:", np.mean(f1_scores))
print("Macro Average Precision:", macro_precision)
print("Macro Average Recall:", macro_recall)
print("Macro Average F1-score:", macro_f1)
# Out:
# Confusion matrix for fold 1:
#  [[152  12]
#  [ 12  45]]
# Confusion matrix for fold 2:
#  [[152  12]
#  [  8  49]]
# Confusion matrix for fold 3:
#  [[154  10]
#  [ 16  41]]
# Confusion matrix for fold 4:
#  [[156   8]
#  [  7  50]]
# Confusion matrix for fold 5:
#  [[155   9]
#  [ 14  43]]
# Confusion matrix for fold 6:
#  [[149  15]
#  [  9  48]]
# Confusion matrix for fold 7:
#  [[151  13]
#  [  9  48]]
# Confusion matrix for fold 8:
#  [[150  14]
#  [ 10  46]]
# Model Accuracy: 0.8992595639654464
# Weighted Average Precision: 0.9004018835606267
# Weighted Average Recall: 0.8992595639654464
# Weighted Average F1-score: 0.89942619131596
# Macro Average Precision: 0.8520833333333333
# Macro Average Recall: 0.8680313588850175
# Macro Average F1-score: 0.8595146871008941

# %%
# Get feature importances
feature_importances = xgb.feature_importances_

# Create a DataFrame of features and their importances
features_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances
})

# Sort the DataFrame by importance in descending order
features_df = features_df.sort_values('Importance', ascending=False)

# Print the feature importances
print(features_df)
# Out:
#                             Feature  Importance
# 26               NumPassedWorkshops    0.314605
# 18  ContinuousAbsenceSinceLastLogin    0.197651
# 15                 MHLearningSchool    0.062819
# 4                  PriorityDistrict    0.051491
# 28   NumWorkshopsWithNullPassStatus    0.032968
# 22                         Rejected    0.024548
# 16                   PathologyScore    0.023016
# 3                      FamilyIncome    0.021841
# 29        TotalNumEnrolledWorkshops    0.021531
# 19                          Awarded    0.020606
# 33         NotRecordedSessionsCount    0.019818
# 30            AttendedSessionsCount    0.019608
# 14               MHSocialBehavioral    0.019356
# 27            NumWithdrawnWorkshops    0.019332
# 0                 AgeAtregistration    0.017900
# 25               NumFailedWorkshops    0.017263
# 31         NotAttendedSessionsCount    0.016321
# 17                   RegularPresent    0.015835
# 24         NumOfAttemptedActivities    0.015494
# 20                              New    0.014948
# 32             ExcusedSessionsCount    0.014581
# 23                          Working    0.011665
# 5                SocioeconomicScore    0.011040
# 1                               Sex    0.009190
# 2                    PrioritySchool    0.006573
# 10             MHSpeechCommuication    0.000000
# 21                          Pending    0.000000
# 9              MHNeurodevelopmental    0.000000
# 12                    MHPsychiatric    0.000000
# 11                      MHEmotional    0.000000
# 8       PHDevelopmentalCoordination    0.000000
# 7                  PHChronicDisease    0.000000
# 6                      PHDisability    0.000000
# 13              MHFamilyEnvironment    0.000000

# %%
# Plot feature importance
plt.figure(figsize=(10, 6))
plt.title("Feature importances")
plt.barh(features_df['Feature'], features_df['Importance'], color='b', align='center')
plt.xlabel("Feature Importance")
plt.gca().invert_yaxis()

# Save the plot as a PNG file
plt.savefig('../visualizations/featureimp-xg-boost.png', bbox_inches='tight')

plt.show()

# %%
# Select the top 10 features
top_features = features_df['Feature'][:25]

# Select only the top features from X
X_top_features = X[top_features]
X_normalized = scaler.fit_transform(X_top_features)

# Lists to store the metrics of each fold
confusion_matrices = []
accuracies = []
precisions = []
recalls = []
f1_scores = []

# Perform stratified K-fold cross-validation with 8 folds
skf = StratifiedKFold(n_splits=8)

# Train an XGBoost classifier on each fold
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

for train_index, test_index in skf.split(X_normalized, y):
    X_train, X_test = X_normalized[train_index], X_normalized[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # Train the XGBoost classifier
    xgb.fit(X_train, y_train)
    
    # Make predictions on the test set
    y_pred = xgb.predict(X_test)
    
    # Compute the confusion matrix and store it in the list
    cm = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(cm)
    
    # Compute the metrics and store them in the lists
    accuracies.append(accuracy_score(y_test, y_pred))
    precisions.append(precision_score(y_test, y_pred, average='weighted'))
    recalls.append(recall_score(y_test, y_pred, average='weighted'))
    f1_scores.append(f1_score(y_test, y_pred, average='weighted'))

# %%
# Print the confusion matrices
for i, cm in enumerate(confusion_matrices):
    print(f"Confusion matrix for fold {i+1}:\n", cm)
    
# Compute the macro averages
macro_precision = precision_score(y_test, y_pred, average='macro')
macro_recall = recall_score(y_test, y_pred, average='macro')
macro_f1 = f1_score(y_test, y_pred, average='macro')

# Print the metrics
print("Model Accuracy:", np.mean(accuracies))
print("Weighted Average Precision:", np.mean(precisions))
print("Weighted Average Recall:", np.mean(recalls))
print("Weighted Average F1-score:", np.mean(f1_scores))
print("Macro Average Precision:", macro_precision)
print("Macro Average Recall:", macro_recall)
print("Macro Average F1-score:", macro_f1)
# Out:
# Confusion matrix for fold 1:
#  [[146  18]
#  [ 11  46]]
# Confusion matrix for fold 2:
#  [[149  15]
#  [  6  51]]
# Confusion matrix for fold 3:
#  [[152  12]
#  [ 19  38]]
# Confusion matrix for fold 4:
#  [[158   6]
#  [ 13  44]]
# Confusion matrix for fold 5:
#  [[153  11]
#  [ 16  41]]
# Confusion matrix for fold 6:
#  [[151  13]
#  [  9  48]]
# Confusion matrix for fold 7:
#  [[151  13]
#  [  8  49]]
# Confusion matrix for fold 8:
#  [[151  13]
#  [ 10  46]]
# Model Accuracy: 0.890777972027972
# Weighted Average Precision: 0.8926343671397289
# Weighted Average Recall: 0.890777972027972
# Weighted Average F1-score: 0.8908772099554384
# Macro Average Precision: 0.8587746078534583
# Macro Average Recall: 0.8710801393728222
# Macro Average F1-score: 0.8646153846153847

# %%
import matplotlib.pyplot as plt

# Count the number of students in each class
class_counts = df['DroppedOut'].value_counts()

# Change the class labels
class_counts.index = ['Persisted', 'Dropped Out']

# Create a pie chart of the counts
class_counts.plot(kind='pie', autopct='%1.1f%%')

plt.title('Proportion of Students in each Predicted Class')
plt.ylabel('')  # This line removes the y-axis label for the pie chart

# Save the figure
plt.savefig('pie_chart.png', bbox_inches='tight')

plt.show()

# %%
significant_features = ['PathologyScore', 'SocioeconomicScore', 'MHNeurodevelopmental', 'MHPsychiatric', 'MHFamilyEnvironment', 'MHSocialBehavioral', 'MHLearningSchool']

# Create boxplots of the significant features for each class
plt.figure(figsize=(10, 6))
for feature in significant_features:
    plt.boxplot([X.loc[y == 0, feature], X.loc[y == 1, feature]], labels=['Persist', 'Drop Out'])
    plt.xlabel('Outcome')
    plt.ylabel(feature)
    plt.title(f'{feature} Boxplots for Persisting & Dropping Out')
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of features to plot
features = ['PathologyScore', 'SocioeconomicScore']  # replace with your features

# For each feature, we create a separate box plot for each class
for feature in features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='DroppedOut', y=feature, data=df)
    plt.title('Box plot of {} by class'.format(feature))
    plt.show()
